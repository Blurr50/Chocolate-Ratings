# %% [markdown]
# **Final Project Proposal**
#
# Selene Myhre
#
# Chocolate

# %% [markdown]
# I hope that I can answer whether there is a connection between ratings of various chocolate bars and the variety of bean used  in their production, as well as comparing it to the cacao percentage in each bar.
#
# I thought this would be an interesting question, and I also really like chocolate, and comparing various different types of chocolate. I also really enjoy baking, and finding out the qualities of the best tasting chocolate would be helpful for me to improve my sourcing of ingredients.
#
# I hope to see a correlation between certain aspects of a chocolate bar and its ratings by experts, potentially so that I could make more informed decisions when I want to buy chocolate, both to simply eat and to bake with.

# %% [markdown]
# **Data**
#
# Data taken from https://www.kaggle.com/datasets/rtatman/chocolate-bar-ratings/data
#
# The observations are 1721 chocolate bars, with variables being the region that made the bar, the cocoa percent of each bar, the manufacturing location, the average rating from 1 - 5 from experts, and the type of cacao bean used (often left blank).
#
# There are no ethical concerns with this data, this specific dataset is public domain.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
location = "C:/Users/chrys/Data Science 101/Chocolate-Ratings/Data/flavors_of_cacao.csv"
DF = pd.read_csv(location)
DF.columns = DF.columns.str.replace('\n', '')
#DF.columns = DF.columns.str.replace(' ', '_')
DF
# Out:
#        Company Specific Bean Origin or Bar Name   REF  ReviewDate  \
# 0     A. Morin                      Agua Grande  1876        2016
# 1     A. Morin                            Kpime  1676        2015
# 2     A. Morin                           Atsane  1676        2015
# 3     A. Morin                            Akata  1680        2015
# 4     A. Morin                           Quilla  1704        2015
# ...        ...                              ...   ...         ...
# 1790    Zotter                             Peru   647        2011
# 1791    Zotter                            Congo   749        2011
# 1792    Zotter                     Kerala State   749        2011
# 1793    Zotter                     Kerala State   781        2011
# 1794    Zotter               Brazil, Mitzi Blue   486        2010
#
#      CocoaPercent CompanyLocation  Rating   BeanType Broad BeanOrigin
# 0             63%          France    3.75                    Sao Tome
# ...

# %%
DF.columns
# Out:
# Index(['Company (Maker-if_known)', 'Specific_Bean_Originor_Bar_Name', 'REF',
#        'ReviewDate', 'CocoaPercent', 'CompanyLocation', 'Rating', 'BeanType',
#        'Broad_BeanOrigin'],
#       dtype='object')

# %%
var = 'Company'
DF[var].value_counts()
# Out:
# Company
# Soma                 47
# Bonnat               27
# Fresco               26
# Pralus               25
# A. Morin             23
#                      ..
# Chocablog             1
# Marigold's Finest     1
# Chloe Chocolat        1
# Chequessett           1
# Ki' Xocolatl          1
# Name: count, Length: 416, dtype: int64

# %%
var = 'CompanyLocation'
DF[var].value_counts()
# Out:
# CompanyLocation
# U.S.A.               764
# France               156
# Canada               125
# U.K.                  96
# Italy                 63
# Ecuador               54
# Australia             49
# Belgium               40
# Switzerland           38
# Germany               35
# Austria               26
# Spain                 25
# Colombia              23
# Hungary               22
# Venezuela             20
# Japan                 17
# Brazil                17
# Peru                  17
# Madagascar            17
# New Zealand           17
# Denmark               15
# Vietnam               11
# Scotland              10
# Guatemala             10
# Israel                 9
# Costa Rica             9
# Argentina              9
# Poland                 8
# Lithuania              6
# Honduras               6
# South Korea            5
# Nicaragua              5
# Sweden                 5
# Domincan Republic      5
# Ireland                4
# Netherlands            4
# ...

# %%
var = 'Rating'
DF[var].dtype
# Out:
# dtype('float64')

# %%
fig = px.histogram(DF, x = 'Rating',
                   #nbins = 20
                   )
fig.update_layout(bargap = 0.05,
                  title = 'Distribution of Ratings',
                  autosize = False,
                  height = 600,
                  width = 1000
                 )
fig.show()

# %% [markdown]
# **Initial Exploration**
#
# There are 1795 observations and 9 variables
#
# Variables -
#
#     Company - categorical, of minor importance since it might skew data but not largely considered since the goal of the dataset is to get some generalizable data, which is impossible when sorting by company.
#
#     Specific bean origin - categorical, place where the beans were grown
#
#     REF - value based on recency of data - going unused since it would be hard to quantify, especially since the dataset also measures year.
#
#     Review Data - date of the expert review - numerical - might be used sparingly, but hard to draw any conclusions based on when a review was made, at least on initial view
#
#     Cocoa percent - percentage of cocoa in the bar - numerical - Very important, though it is notable that this dataset has an emphasis on dark chocolate. Will be directly used in dataset.
#
#     Company location - where the factory that processes the final bar is located. - categorical - Unsure where this would be used, but might be potentially impactful. Often not immediately obvious on chocolate bar, might be hard to easily compare with outside chocolate brands later
#
#     Expert Rating - rating from 1 to 5 given by various experts - 1 is bad, 2 is good but at least 1 flaw, 3 is good, 3.75 is very good, 4 is premium - above average in every aspect, 5 is Trancending beyond what thought possible. - categorical,
#
#     Bean Type - specific variety of cacao bean used in making the bar - going unused since dataset has large holes in this variable which might create bias.
#
#     Broad bean origin - categorical, place where beans were grown. Much easier to create groups and compare their data when compared to specific bean origin,
#
#
# **Initial Analysis**
#
# Potential biases
#
# *Large number of production facilities in US, France, Canada, might impact data*
#
# *Some gaps in companies surveyed might impact data*
#
# *Reviews can always be biased*
#
# *Dataset has emphasis on dark chocolate, dataset is not generalizable to other varieties of chocolate*
#
# There is a relative bell curve of ratings, though there are many more very low rated chocolate bars than very highly rated ones.

# %% [markdown]
# **Grouping**
#
# I am more of a solitary worker, and I am also unsure if my dataset would be related enough to another student's to be able to draw a conclusion using both.
#
# If you think someone else's dataset would mesh well with my data, then by all means group me with them. I'm just not completely sure how related my classmate's submissions would be and how easy it would be to tie the data together.
